# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r"C:/Users/Tanvi Parihar/Downloads/Python_Diwali_Sales_Analysis/Python_Diwali_Sales_Analysis/Diwali Sales Data.csv", encoding='latin1')

# %%
print(df.head())
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace=True, errors='ignore')
print(df.head(5))
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df['Amount']=df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
ax = sns.countplot(x="Gender",hue="Gender",data=df, palette="deep")

# Add counts on top of bars
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2, height + 1, int(height), ha="center")

plt.show()

# %%
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Gender',y='Amount',data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
plt.show()

# %% [markdown]
# from the above graphs we can conclude that most of the buyers are female and females are spending more money as compared to men

# %%
ax = sns.countplot(x="Age Group",hue="Gender",data=df, palette="deep")
# Add counts on top of bars
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2, height + 1, int(height), ha="center")
plt.show()

# %%
ax = sns.countplot(x="Age Group", data=df, color=sns.color_palette("deep")[0])
plt.show()

# %%
sales_age=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Age Group',y='Amount',data=sales_age) 
plt.show()

# %% [markdown]
# from the above graphs most the buyers are female of age group 26-35 years

# %%
# Create the sales_state DataFrame
sales_state = df.groupby('State')['Orders'].sum().reset_index()

plt.figure(figsize=(10, 12))
ax = sns.barplot(y='State', x='Orders', hue='State', data=sales_state, palette='coolwarm', dodge=False, legend=False)

# Add value labels
for bar in ax.patches:
    ax.text(bar.get_width() + 5, bar.get_y() + bar.get_height()/2,
            int(bar.get_width()), va='center')

plt.title('Total Orders by State')
plt.tight_layout()
plt.show()

# %% [markdown]
# sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
# plt.figure(figsize=(10, 12))  # Tall figure for horizontal bars
# ax = sns.barplot(y='State', x='Amount', data=sales_state, palette='coolwarm')
# plt.title('Total Spent by State')
# plt.xlabel('Total Amount')
# plt.ylabel('State')
# plt.tight_layout()
# plt.show()

# %%
from the above graph most of the orders from uttar pradesh,maharastra, karnataka

# %%
ax = sns.countplot(x="Marital_Status",hue='Marital_Status',data=df, palette="deep")
plt.show()

# %%
# Clean and prepare data
df['Marital_Status'] = df['Marital_Status'].astype(str).str.strip()
df = df.dropna(subset=['Marital_Status'])

# Group and sort
sales_state = df.groupby('Marital_Status', as_index=False)['Amount'].sum()
sales_state = sales_state.sort_values(by='Amount', ascending=False)

# Plot
plt.figure(figsize=(8, 5))
ax = sns.barplot(
    y='Marital_Status',
    x='Amount',
    hue='Marital_Status',          # fixes the warning
    data=sales_state,
    palette='coolwarm',
    dodge=False,
    legend=False                   # hides redundant legend
)

# Add value labels
for bar in ax.patches:
    ax.text(bar.get_width() + 10000,
            bar.get_y() + bar.get_height() / 2,
            int(bar.get_width()),
            va='center')

plt.title('Total Spent according to Marital Status')
plt.xlabel('Total Amount')
plt.ylabel('Marital Status')
plt.tight_layout()
plt.show()

# %%
from the above graph we can say that most of the buyers are married

# %%
plt.figure(figsize=(8, 10))  # Taller plot for horizontal bars

# Use `hue="Occupation"` and disable the legend
ax = sns.countplot(y="Occupation", hue="Occupation", data=df, palette="deep", legend=False)

plt.title("Count of Customers by Occupation")
plt.tight_layout()
plt.show()

# %%
# Grouping by Occupation and summing the Amount
sales_occupation = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

plt.figure(figsize=(8, 6))  # Wider for clearer labels

# Assign hue and disable legend to avoid warning
ax = sns.barplot(y='Occupation', x='Amount', hue='Occupation', data=sales_occupation,
                 palette='coolwarm', dodge=False, legend=False)

plt.title('Total Spent According to Occupation')
plt.xlabel('Total Amount')
plt.ylabel('Occupation')
plt.tight_layout()
plt.show()

# %% [markdown]
# from above graph we can say that most of the buyers is from IT sector , healthcare, aviation

# %%
plt.figure(figsize=(12, 6))  # Make the figure wider

# Add hue=x and disable legend to avoid FutureWarning
ax = sns.countplot(x="Product_Category", hue="Product_Category", data=df, palette="deep", legend=False)

plt.xticks(rotation=45, ha='right')  # Rotate labels for better fit
plt.title("Count of Product Categories")
plt.tight_layout()
plt.show()

# %%
# Grouping and sorting
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum()
sales_state = sales_state.sort_values(by='Amount', ascending=False)

# Plotting
plt.figure(figsize=(5, 6))  # Slightly wider for clarity
ax = sns.barplot(
    y='Product_Category',
    x='Amount',
    hue='Product_Category',        #  to avoid FutureWarning
    data=sales_state,
    palette='coolwarm',
    dodge=False,
    legend=False                   # hides duplicate legend
)

plt.title('Total Amount Spent by Product Category')
plt.xlabel('Total Amount')
plt.ylabel('Product Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# most sold products are food , clothing

# %% [markdown]
# conclusion: married women age groups 26-35 years from up, maharastra and karnataka working in IT, hralthcare, aviation are more likely to buy products from food, clothing and electronic category
